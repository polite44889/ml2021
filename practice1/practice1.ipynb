# %% [markdown]
# # Практична робота 1
# # Студента групи МІТ-31
# # Ярощука Назар Юрійовича

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
df = pd.read_csv("practice1_data.csv")
df.head(10)
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  2.163950  0.015729 -1.136593  2.182571 -1.552051 -0.909067  1.791084
# 1  1.364464 -1.359741 -1.881798 -0.484231 -1.974301 -0.017010  2.184909
# 2  1.237133  0.945965 -0.008633  0.889645  0.348132 -1.863290 -1.093229
# 3  0.530019  2.739019  1.168152 -0.182967 -0.313546  1.274500  1.097952
# 4 -1.169403 -0.387841  0.049067 -2.136358 -1.839488 -0.635955 -0.136341
# 5  2.632567 -2.187044 -2.877435  1.214570 -0.932406 -1.751738 -0.371274
# 6  0.414880 -0.157428  1.192164  1.315924 -1.487844 -1.530894 -1.467259
# 7  0.696428  2.336794  0.937671 -1.408921  0.986726  1.651799  2.112990
# 8 -2.011219 -0.851366  1.213547  1.393759  0.387996  1.605899  2.790490
# 9 -0.584189 -3.062913 -1.940569 -0.740922 -0.147745 -0.961257  1.870423
#
#          x8        x9       x10  classes
# 0 -1.094894  0.308272 -0.912365        0
# 1 -1.012308 -0.774774 -3.702803        0
# 2  0.057705  1.646754 -0.834884        2
# ...

# %%
df = df.drop("x3", axis = 1)
df = df.drop("x4", axis = 1)
df = df.drop("x5", axis = 1)
df = df.drop("x6", axis = 1)
df = df.drop("x9", axis = 1)
df = df.drop("x10", axis = 1)
df.head(10)
# Out:
#          x1        x2        x7        x8  classes
# 0  2.163950  0.015729  1.791084 -1.094894        0
# 1  1.364464 -1.359741  2.184909 -1.012308        0
# 2  1.237133  0.945965 -1.093229  0.057705        2
# 3  0.530019  2.739019  1.097952 -0.909685        1
# 4 -1.169403 -0.387841 -0.136341  0.357952        2
# 5  2.632567 -2.187044 -0.371274 -1.623788        0
# 6  0.414880 -0.157428 -1.467259  2.600887        2
# 7  0.696428  2.336794  2.112990 -1.268736        0
# 8 -2.011219 -0.851366  2.790490  1.318649        2
# 9 -0.584189 -3.062913  1.870423 -0.814882        0

# %%
df.describe()
# Out:
#                 x1           x2           x7           x8      classes
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean      0.550329    -0.275385     0.056311    -0.244578     1.497333
# std       1.489842     1.711574     1.560251     1.594473     1.117807
# min      -4.857101    -5.631583    -4.975684    -4.642937     0.000000
# 25%      -0.437339    -1.423198    -1.112853    -1.338483     0.000000
# 50%       0.601106    -0.427568    -0.064162    -0.432473     1.000000
# 75%       1.566922     0.800646     1.215963     0.844740     2.000000
# max       5.147879     5.616177     4.344007     6.598312     3.000000

# %%
df["classes"].value_counts()
# Out:
# 0    376
# 2    376
# 1    375
# 3    373
# Name: classes, dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,5), dpi = 100)
fig.suptitle('Distribution of (x1, x2, x7, x8) per classes')

sns.kdeplot(ax = axes[0,0], data = df, x = 'x1', hue = "classes", alpha = 0.5, shade = True)
axes[0,0].set_xlabel("x1")
axes[0,0].get_legend().remove()

sns.kdeplot(ax = axes[0,1], data = df, x = 'x2', hue = "classes", alpha = 0.5, shade = True)
axes[0,1].set_xlabel("x2")
axes[0,1].get_legend().remove()

sns.kdeplot(ax = axes[1,0], data = df, x = 'x7', hue = "classes", alpha = 0.2, shade = True)
axes[1,0].set_xlabel("x7")
axes[1,0].get_legend().remove()

sns.kdeplot(ax = axes[1,1], data = df, x = 'x8', hue = "classes", alpha = 0.5, shade = True)
axes[1,1].set_xlabel("x8")
axes[1,1].get_legend().remove()


plt.tight_layout()

# %%
plt.figure(figsize = (7, 3), dpi = 100)
sns.scatterplot(data = df, x = 'x1', y = 'x2', hue = "classes")
plt.title("Classes data based on x1 and x2")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize = (7, 3), dpi = 100)
sns.scatterplot(data = df, x = 'x7', y = 'x8', hue = "classes")
plt.title("Classes data based on x7 and x8")
plt.xlabel("x7")
plt.ylabel("x8")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,5), dpi = 100)

#Mean x1
sns.boxplot(ax = axes[0,0], data = df, x = "classes", y = 'x1')
axes[0,0].set_xlabel(None)
axes[0,0].set_ylabel(None)
axes[0,0].set_title("Mean x1")


#Mean x2
sns.boxplot(ax = axes[0,1], data = df, x = "classes", y = 'x2')
axes[0,1].set_xlabel(None)
axes[0,1].set_ylabel(None)
axes[0,1].set_title("Mean x2")

#Mean x7
sns.boxplot(ax = axes[1,0], data = df, x = "classes", y = 'x7')
axes[1,0].set_xlabel(None)
axes[1,0].set_ylabel(None)
axes[1,0].set_title("Mean x7")

#Mean x8
sns.boxplot(ax = axes[1,1], data = df, x = "classes", y = 'x8')
axes[1,1].set_xlabel(None)
axes[1,1].set_ylabel(None)
axes[1,1].set_title("Mean x8")

plt.tight_layout()
plt.subplots_adjust(hspace=0.5)

# %%
plt.figure(figsize = (8, 4), dpi = 100)
sns.heatmap(df.corr(), annot = True, cmap = "coolwarm", vmin = -1, vmax = 1)
plt.title("Correlation map between variables")
plt.show()

# %%
X = df.drop("classes", axis = 1)
y = df["classes"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

from sklearn.preprocessing import StandardScaler # import the scaler
scaler = StandardScaler() # initiate it
Scaled_X_train = scaler.fit_transform(X_train) #fit the parameters and use it to trannsform the traning data
Scaled_X_test = scaler.transform(X_test) #transform the test data

from sklearn.linear_model import LogisticRegression # import the classifier
log_model = LogisticRegression() #initiate it
log_model.fit(Scaled_X_train, y_train) #fit the model to the training data

y_pred = log_model.predict(Scaled_X_test)

from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, classification_report

confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(dpi = 120)
plot_confusion_matrix(log_model, Scaled_X_test, y_test, ax = ax);

# %%
acc_score = accuracy_score(y_test, y_pred)
round(acc_score, 2)

print(classification_report(y_test, y_pred)) # Hint: try it without using the print() method
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.62      0.60        74
#            1       0.54      0.68      0.60        73
#            2       0.45      0.41      0.43        68
#            3       0.70      0.54      0.61        85
#
#     accuracy                           0.57       300
#    macro avg       0.57      0.56      0.56       300
# weighted avg       0.57      0.57      0.57       300
